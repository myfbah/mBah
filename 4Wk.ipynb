# %%
import pandas as pd
import numpy as np

# %%
 HD = pd.read_csv("Holiday Destinations.csv")

print(HD)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-750d54d72e87> in <module>
# ----> 1 HD = pd.read_csv("Holiday Destinations.csv")
#       2
#       3 print(HD)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
#1.How many rows and columns are there in your file?

HD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          15 non-null     int64
#  1   Destinations        15 non-null     object
#  2   Destination Rating  15 non-null     int64
#  3   Hotel rating        15 non-null     int64
#  4   Inclusive Hotels    15 non-null     int64
#  5   Popular City        15 non-null     object
# dtypes: int64(4), object(2)
# memory usage: 848.0+ bytes

# %%
HD.head(20)
# Out:
#     Unnamed: 0          Destinations  Destination Rating  Hotel rating  \
# 0            1         United States                   8             3
# 1            2        United Kingdom                   7             4
# 2            3                France                   3             5
# 3            4           Netherlands                   1             1
# 4            5               Germany                   4             2
# 5            6              Portugal                   5             5
# 6            7                Mexico                   9             4
# 7            8               Senegal                   4             3
# 8            9                Russia                   2             3
# 9           10          South Africa                   6             4
# 10          11                Turkey                   5             5
# 11          12  United Arab Emirates                   9             2
# ...

# %%
# 2. Print row 3-8 ( using iloc/loc)
HD.iloc[2:8]
# Out:
#    Unnamed: 0 Destinations  Destination Rating  Hotel rating  \
# 2           3       France                   3             5
# 3           4  Netherlands                   1             1
# 4           5      Germany                   4             2
# 5           6     Portugal                   5             5
# 6           7       Mexico                   9             4
# 7           8      Senegal                   4             3
#
#    Inclusive Hotels Popular City
# 2                19        Paris
# 3                 1    Amsterdam
# 4                23       Berlin
# 5                23       Lisbon
# 6                15  Mexico City
# 7                12        Dakar

# %%
# 2. Print row 3-8 ( using iloc/loc)
HD.loc[2:7]
# Out:
#    Unnamed: 0 Destinations  Destination Rating  Hotel rating  \
# 2           3       France                   3             5
# 3           4  Netherlands                   1             1
# 4           5      Germany                   4             2
# 5           6     Portugal                   5             5
# 6           7       Mexico                   9             4
# 7           8      Senegal                   4             3
#
#    Inclusive Hotels Popular City
# 2                19        Paris
# 3                 1    Amsterdam
# 4                23       Berlin
# 5                23       Lisbon
# 6                15  Mexico City
# 7                12        Dakar

# %%
# 3. Find the mean number of all-inclusive hotels across all destinations.

HD["Inclusive Hotels"].mean()
# Out:
# 14.2

# %%
# 4. Find the lowest scoring destination.
# 5. Find the highest scoring destination.
print(HD["Destination Rating"].min(), "------", HD["Destination Rating"].max())
# Out:
# 1 ------ 9

# %%
HDdr = HD["Destination Rating"]

HD.loc[HDdr == 1]
# Out:
#     Unnamed: 0 Destinations  Destination Rating  Hotel rating  \
# 3            4  Netherlands                   1             1
# 14          15     Malaysia                   1             4
#
#     Inclusive Hotels  Popular City
# 3                  1     Amsterdam
# 14                10  Kuala Lumpur

# %%
HD.loc[HDdr == 9]
# Out:
#     Unnamed: 0          Destinations  Destination Rating  Hotel rating  \
# 6            7                Mexico                   9             4
# 11          12  United Arab Emirates                   9             2
#
#     Inclusive Hotels Popular City
# 6                 15  Mexico City
# 11                 7        Dubai

# %%
# 6. Find all the destinations where there are more than 9 all-inclusive hotels. 
HDih = HD["Inclusive Hotels"]

HD.loc[HDih > 9]
# Out:
#     Unnamed: 0    Destinations  Destination Rating  Hotel rating  \
# 0            1   United States                   8             3
# 1            2  United Kingdom                   7             4
# 2            3          France                   3             5
# 4            5         Germany                   4             2
# 5            6        Portugal                   5             5
# 6            7          Mexico                   9             4
# 7            8         Senegal                   4             3
# 10          11          Turkey                   5             5
# 12          13           India                   3             1
# 13          14           China                   2             3
# 14          15        Malaysia                   1             4
#
#     Inclusive Hotels  Popular City
# 0                 25      New York
# 1                 17        London
# 2                 19         Paris
# 4                 23        Berlin
# ...

# %%
# 7. Filter the data by score above 8. 
HD[(HDih > 9) & (HDdr > 8)]
# Out:
#    Unnamed: 0 Destinations  Destination Rating  Hotel rating  \
# 6           7       Mexico                   9             4
#
#    Inclusive Hotels Popular City
# 6                15  Mexico City

# %%
# 8. Filter the data score below 2 ( I need to know if these destinations should be removed or there is a problem) 

HD[(HDih > 9) & (HDdr < 3)]
# Out:
#     Unnamed: 0 Destinations  Destination Rating  Hotel rating  \
# 13          14        China                   2             3
# 14          15     Malaysia                   1             4
#
#     Inclusive Hotels  Popular City
# 13                14       Beijing
# 14                10  Kuala Lumpur

# %%
# 9. Is there a correlation between number of all-inclusive hotels and score?
HDdr.corr(HDih)
# Out:
# 0.25367581354085794

# %%
# 10. Create a data visualisation diagram to show destination and highest scores?
HD.plot()
C = ["Destination Rating", "Inclusive Hotels", "Hotel rating"]
HD[C].plot.area()
HD.groupby("Destinations").mean().plot.bar()
HD.plot.bar(x = "Destinations", y = "Destination Rating")
HD.plot.bar(x = "Destinations", y = "Hotel rating") 
HD.plot.bar(x = "Destinations", y = "Inclusive Hotels")
# Out:
# <AxesSubplot:xlabel='Destinations'>

# %%
HD[C].plot.box()
HD.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'Destination Rating'}>],
#        [<AxesSubplot:title={'center':'Hotel rating'}>,
#         <AxesSubplot:title={'center':'Inclusive Hotels'}>]], dtype=object)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(HD, figsize=(10,10))
# Out:
# array([[<AxesSubplot:xlabel='Unnamed: 0', ylabel='Unnamed: 0'>,
#         <AxesSubplot:xlabel='Destination Rating', ylabel='Unnamed: 0'>,
#         <AxesSubplot:xlabel='Hotel rating', ylabel='Unnamed: 0'>,
#         <AxesSubplot:xlabel='Inclusive Hotels', ylabel='Unnamed: 0'>],
#        [<AxesSubplot:xlabel='Unnamed: 0', ylabel='Destination Rating'>,
#         <AxesSubplot:xlabel='Destination Rating', ylabel='Destination Rating'>,
#         <AxesSubplot:xlabel='Hotel rating', ylabel='Destination Rating'>,
#         <AxesSubplot:xlabel='Inclusive Hotels', ylabel='Destination Rating'>],
#        [<AxesSubplot:xlabel='Unnamed: 0', ylabel='Hotel rating'>,
#         <AxesSubplot:xlabel='Destination Rating', ylabel='Hotel rating'>,
#         <AxesSubplot:xlabel='Hotel rating', ylabel='Hotel rating'>,
#         <AxesSubplot:xlabel='Inclusive Hotels', ylabel='Hotel rating'>],
#        [<AxesSubplot:xlabel='Unnamed: 0', ylabel='Inclusive Hotels'>,
# ...
